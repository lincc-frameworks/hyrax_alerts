# %% [markdown]
# # Basic smoke test notebook

# %%
from hyrax_alerts.process_alerts import process_alerts

process_alerts(config_filepath="./basic_test_config.toml")

# %%
print("All tests passed.")
# Out:
# All tests passed.

# %%
# %tensorboard --logdir=./logs --port=6006

# %%
from hyrax_alerts.train_on_alerts import train_on_alerts

train_on_alerts(config_filepath="./basic_test_config.toml")
